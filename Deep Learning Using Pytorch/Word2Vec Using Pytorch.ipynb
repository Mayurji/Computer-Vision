# %% [markdown]
# **Word embeddings are a representation of the *semantics* of a word, efficiently encoding semantic information that might be relevant to the task at hand. You can embed other things too: part of speech tags, parse trees, anything! The idea of feature embeddings is central to the field.**
#
# * [Pytorch Tutorial on Word Embedding](https://pytorch.org/tutorials/beginner/nlp/word_embeddings_tutorial.html)
# * [Distributional Semantics](https://en.wikipedia.org/wiki/Distributional_semantics)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy

# %%
torch.manual_seed(42)

# %%
anna = "anna.txt"
lines = []
trigrams = []
with open(anna,'r') as data:
    for k,line in enumerate(data.readlines()):
        if k > 5000:
            break
        if line.endswith("\n"):
            line = line.strip("\n")
            if len(line) > 1:
                lines.append(line)
            test_sentence = line.split()
            if len(test_sentence) >= 3:
                trigrams += [([test_sentence[i], test_sentence[i + 1]], test_sentence[i + 2]) for i in range(len(test_sentence) - 2)]

# %%
words_list = [wrd for sent in lines for wrd in sent.split()]

# %%
word_lst = set(words_list)

# %%
wrd_to_idx = {wrd: i for i,wrd in enumerate(word_lst)}

# %%
len(trigrams)
# Out:
# 34412

# %%
#Ngram Language Model
CONTEXT_SIZE = 2
EMBEDDING_DIM = 100

class NGramLanguageModel(nn.Module):
    
    def __init__(self, vocab_size, embedding_dim, context_size):
        super(NGramLanguageModel,self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.linear1 = nn.Linear(context_size * embedding_dim, 128)
        self.linear2 = nn.Linear(128, vocab_size)
        
    def forward(self, inputs):
        embeds = self.embeddings(inputs).view((1,-1))
        out = F.relu(self.linear1(embeds))
        out = self.linear2(out)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs
    
losses = []
loss_function = nn.NLLLoss()
model = NGramLanguageModel(len(word_lst), EMBEDDING_DIM, CONTEXT_SIZE)
optimizer = optim.SGD(model.parameters(), lr = 0.001)

for epoch in range(10):
    total_loss = 0
    for context, target in trigrams:
        
        context_ids = torch.tensor([wrd_to_idx[w] for w in context],dtype = torch.long)
        model.zero_grad()
        log_probs = model(context_ids)
        loss = loss_function(log_probs,torch.tensor([wrd_to_idx[target]],
                                                   dtype=torch.long))
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        print("Epoch "+str(epoch)+" Total Loss "+str(total_loss))
    losses.append(total_loss)
print(losses)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-17d49416aa1d> in <module>
#      20 losses = []
#      21 loss_function = nn.NLLLoss()
# ---> 22 model = NGramLanguageModel(len(word_lst), EMBEDDING_DIM, CONTEXT_SIZE)
#      23 optimizer = optim.SGD(model.parameters(), lr = 0.001)
#      24
#
# NameError: name 'word_lst' is not defined

# %%
y_pred = model(torch.tensor([1729,276],dtype=torch.long))

# %%
trigrams
# Out:
# [(['Happy', 'families'], 'are'),
#  (['families', 'are'], 'all'),
#  (['are', 'all'], 'alike;'),
#  (['all', 'alike;'], 'every'),
#  (['alike;', 'every'], 'unhappy'),
#  (['every', 'unhappy'], 'family'),
#  (['unhappy', 'family'], 'is'),
#  (['family', 'is'], 'unhappy'),
#  (['is', 'unhappy'], 'in'),
#  (['unhappy', 'in'], 'its'),
#  (['in', 'its'], 'own'),
#  (['Everything', 'was'], 'in'),
#  (['was', 'in'], 'confusion'),
#  (['in', 'confusion'], 'in'),
#  (['confusion', 'in'], 'the'),
#  (['in', 'the'], "Oblonskys'"),
#  (['the', "Oblonskys'"], 'house.'),
#  (["Oblonskys'", 'house.'], 'The'),
#  (['house.', 'The'], 'wife'),
#  (['The', 'wife'], 'had'),
#  (['discovered', 'that'], 'the'),
#  (['that', 'the'], 'husband'),
#  (['the', 'husband'], 'was'),
#  (['husband', 'was'], 'carrying'),
#  (['was', 'carrying'], 'on'),
#  (['carrying', 'on'], 'an'),
#  (['on', 'an'], 'intrigue'),
#  (['an', 'intrigue'], 'with'),
#  (['intrigue', 'with'], 'a'),
#  (['with', 'a'], 'French'),
#  (['girl,', 'who'], 'had'),
#  (['who', 'had'], 'been'),
#  (['had', 'been'], 'a'),
#  (['been', 'a'], 'governess'),
#  (['a', 'governess'], 'in'),
#  (['governess', 'in'], 'their'),
#  (['in', 'their'], 'family,'),
#  (['their', 'family,'], 'and'),
#  (['family,', 'and'], 'she'),
#  (['and', 'she'], 'had'),
#  (['she', 'had'], 'announced'),
#  (['had', 'announced'], 'to'),
#  (['her', 'husband'], 'that'),
#  (['husband', 'that'], 'she'),
#  (['that', 'she'], 'could'),
#  (['she', 'could'], 'not'),
#  (['could', 'not'], 'go'),
#  (['not', 'go'], 'on'),
#  (['go', 'on'], 'living'),
#  (['on', 'living'], 'in'),
#  (['living', 'in'], 'the'),
#  (['in', 'the'], 'same'),
#  (['the', 'same'], 'house'),
#  (['same', 'house'], 'with'),
#  (['house', 'with'], 'him.'),
#  (['This', 'position'], 'of'),
#  (['position', 'of'], 'affairs'),
#  (['of', 'affairs'], 'had'),
#  (['affairs', 'had'], 'now'),
#  (['had', 'now'], 'lasted'),
#  (['now', 'lasted'], 'three'),
#  (['lasted', 'three'], 'days,'),
#  (['three', 'days,'], 'and'),
#  (['days,', 'and'], 'not'),
#  (['and', 'not'], 'only'),
#  (['not', 'only'], 'the'),
#  (['husband', 'and'], 'wife'),
#  (['and', 'wife'], 'themselves,'),
#  (['wife', 'themselves,'], 'but'),
#  (['themselves,', 'but'], 'all'),
#  (['but', 'all'], 'the'),
#  (['all', 'the'], 'members'),
#  (['the', 'members'], 'of'),
#  (['members', 'of'], 'their'),
#  (['of', 'their'], 'family'),
#  (['their', 'family'], 'and'),
#  (['household,', 'were'], 'painfully'),
#  (['were', 'painfully'], 'conscious'),
#  (['painfully', 'conscious'], 'of'),
#  (['conscious', 'of'], 'it.'),
#  (['of', 'it.'], 'Every'),
#  (['it.', 'Every'], 'person'),
#  (['Every', 'person'], 'in'),
#  (['person', 'in'], 'the'),
#  (['in', 'the'], 'house'),
#  (['felt', 'that'], 'there'),
#  (['that', 'there'], 'was'),
#  (['there', 'was'], 'no'),
#  (['was', 'no'], 'sense'),
#  (['no', 'sense'], 'in'),
#  (['sense', 'in'], 'their'),
#  (['in', 'their'], 'living'),
#  (['their', 'living'], 'together,'),
#  (['living', 'together,'], 'and'),
#  (['together,', 'and'], 'that'),
#  (['and', 'that'], 'the'),
#  (['stray', 'people'], 'brought'),
#  (['people', 'brought'], 'together'),
#  (['brought', 'together'], 'by'),
#  (['together', 'by'], 'chance'),
#  (['by', 'chance'], 'in'),
#  (['chance', 'in'], 'any'),
#  (['in', 'any'], 'inn'),
#  (['any', 'inn'], 'had'),
#  (['inn', 'had'], 'more'),
#  (['had', 'more'], 'in'),
#  (['more', 'in'], 'common'),
#  (['with', 'one'], 'another'),
#  (['one', 'another'], 'than'),
#  (['another', 'than'], 'they,'),
#  (['than', 'they,'], 'the'),
#  (['they,', 'the'], 'members'),
#  (['the', 'members'], 'of'),
#  (['members', 'of'], 'the'),
#  (['of', 'the'], 'family'),
#  (['the', 'family'], 'and'),
#  (['family', 'and'], 'household'),
#  (['and', 'household'], 'of'),
#  (['the', 'Oblonskys.'], 'The'),
#  (['Oblonskys.', 'The'], 'wife'),
#  (['The', 'wife'], 'did'),
#  (['wife', 'did'], 'not'),
#  (['did', 'not'], 'leave'),
#  (['not', 'leave'], 'her'),
#  (['leave', 'her'], 'own'),
#  (['her', 'own'], 'room,'),
#  (['own', 'room,'], 'the'),
#  (['room,', 'the'], 'husband'),
#  (['the', 'husband'], 'had'),
#  (['husband', 'had'], 'not'),
#  (['been', 'at'], 'home'),
#  (['at', 'home'], 'for'),
#  (['home', 'for'], 'three'),
#  (['for', 'three'], 'days.'),
#  (['three', 'days.'], 'The'),
#  (['days.', 'The'], 'children'),
#  (['The', 'children'], 'ran'),
#  (['children', 'ran'], 'wild'),
#  (['ran', 'wild'], 'all'),
#  (['wild', 'all'], 'over'),
#  (['all', 'over'], 'the'),
#  (['over', 'the'], 'house;'),
#  (['the', 'English'], 'governess'),
#  (['English', 'governess'], 'quarreled'),
#  (['governess', 'quarreled'], 'with'),
#  (['quarreled', 'with'], 'the'),
#  (['with', 'the'], 'housekeeper,'),
#  (['the', 'housekeeper,'], 'and'),
#  (['housekeeper,', 'and'], 'wrote'),
#  (['and', 'wrote'], 'to'),
#  (['wrote', 'to'], 'a'),
#  (['friend', 'asking'], 'her'),
#  (['asking', 'her'], 'to'),
#  (['her', 'to'], 'look'),
#  (['to', 'look'], 'out'),
#  (['look', 'out'], 'for'),
#  (['out', 'for'], 'a'),
#  (['for', 'a'], 'new'),
#  (['a', 'new'], 'situation'),
#  (['new', 'situation'], 'for'),
#  (['situation', 'for'], 'her;'),
#  (['for', 'her;'], 'the'),
#  (['her;', 'the'], 'man-cook'),
#  (['had', 'walked'], 'off'),
#  (['walked', 'off'], 'the'),
#  (['off', 'the'], 'day'),
#  (['the', 'day'], 'before'),
#  (['day', 'before'], 'just'),
#  (['before', 'just'], 'at'),
#  (['just', 'at'], 'dinner'),
#  (['at', 'dinner'], 'time;'),
#  (['dinner', 'time;'], 'the'),
#  (['time;', 'the'], 'kitchen-maid,'),
#  (['the', 'kitchen-maid,'], 'and'),
#  (['the', 'coachman'], 'had'),
#  (['coachman', 'had'], 'given'),
#  (['had', 'given'], 'warning.'),
#  (['Three', 'days'], 'after'),
#  (['days', 'after'], 'the'),
#  (['after', 'the'], 'quarrel,'),
#  (['the', 'quarrel,'], 'Prince'),
#  (['quarrel,', 'Prince'], 'Stepan'),
#  (['Prince', 'Stepan'], 'Arkadyevitch'),
#  (['Oblonsky--Stiva,', 'as'], 'he'),
#  (['as', 'he'], 'was'),
#  (['he', 'was'], 'called'),
#  (['was', 'called'], 'in'),
#  (['called', 'in'], 'the'),
#  (['in', 'the'], 'fashionable'),
#  (['the', 'fashionable'], 'world--woke'),
#  (['fashionable', 'world--woke'], 'up'),
#  (['world--woke', 'up'], 'at'),
#  (['his', 'usual'], 'hour,'),
#  (['usual', 'hour,'], 'that'),
#  (['hour,', 'that'], 'is,'),
#  (['that', 'is,'], 'at'),
#  (['is,', 'at'], 'eight'),
#  (['at', 'eight'], "o'clock"),
#  (['eight', "o'clock"], 'in'),
#  (["o'clock", 'in'], 'the'),
#  (['in', 'the'], 'morning,'),
#  (['the', 'morning,'], 'not'),
#  (['morning,', 'not'], 'in'),
#  (['not', 'in'], 'his'),
#  (["wife's", 'bedroom,'], 'but'),
#  (['bedroom,', 'but'], 'on'),
#  (['but', 'on'], 'the'),
#  (['on', 'the'], 'leather-covered'),
#  (['the', 'leather-covered'], 'sofa'),
#  (['leather-covered', 'sofa'], 'in'),
#  (['sofa', 'in'], 'his'),
#  (['in', 'his'], 'study.'),
#  (['his', 'study.'], 'He'),
#  (['study.', 'He'], 'turned'),
#  (['over', 'his'], 'stout,'),
#  (['his', 'stout,'], 'well-cared-for'),
#  (['stout,', 'well-cared-for'], 'person'),
#  (['well-cared-for', 'person'], 'on'),
#  (['person', 'on'], 'the'),
#  (['on', 'the'], 'springy'),
#  (['the', 'springy'], 'sofa,'),
#  (['springy', 'sofa,'], 'as'),
#  (['sofa,', 'as'], 'though'),
#  (['as', 'though'], 'he'),
#  (['would', 'sink'], 'into'),
#  (['sink', 'into'], 'a'),
#  (['into', 'a'], 'long'),
#  (['a', 'long'], 'sleep'),
#  (['long', 'sleep'], 'again;'),
#  (['sleep', 'again;'], 'he'),
#  (['again;', 'he'], 'vigorously'),
#  (['he', 'vigorously'], 'embraced'),
#  (['vigorously', 'embraced'], 'the'),
#  (['embraced', 'the'], 'pillow'),
#  (['the', 'pillow'], 'on'),
#  (['the', 'other'], 'side'),
#  (['other', 'side'], 'and'),
#  (['side', 'and'], 'buried'),
#  (['and', 'buried'], 'his'),
#  (['buried', 'his'], 'face'),
#  (['his', 'face'], 'in'),
#  (['face', 'in'], 'it;'),
#  (['in', 'it;'], 'but'),
#  (['it;', 'but'], 'all'),
#  (['but', 'all'], 'at'),
#  (['all', 'at'], 'once'),
#  (['at', 'once'], 'he'),
#  (['once', 'he'], 'jumped'),
#  (['he', 'jumped'], 'up,'),
#  (['sat', 'up'], 'on'),
#  (['up', 'on'], 'the'),
#  (['on', 'the'], 'sofa,'),
#  (['the', 'sofa,'], 'and'),
#  (['sofa,', 'and'], 'opened'),
#  (['and', 'opened'], 'his'),
#  (['opened', 'his'], 'eyes.'),
#  (['"Yes,', 'yes,'], 'how'),
#  (['yes,', 'how'], 'was'),
#  (['how', 'was'], 'it'),
#  (['was', 'it'], 'now?"'),
#  (['it', 'now?"'], 'he'),
#  (['now?"', 'he'], 'thought,'),
#  (['he', 'thought,'], 'going'),
#  (['thought,', 'going'], 'over'),
#  (['going', 'over'], 'his'),
#  (['over', 'his'], 'dream.'),
#  (['his', 'dream.'], '"Now,'),
#  (['dream.', '"Now,'], 'how'),
#  (['was', 'it?'], 'To'),
#  (['it?', 'To'], 'be'),
#  (['To', 'be'], 'sure!'),
#  (['be', 'sure!'], 'Alabin'),
#  (['sure!', 'Alabin'], 'was'),
#  (['Alabin', 'was'], 'giving'),
#  (['was', 'giving'], 'a'),
#  (['giving', 'a'], 'dinner'),
#  (['a', 'dinner'], 'at'),
#  (['dinner', 'at'], 'Darmstadt;'),
#  (['at', 'Darmstadt;'], 'no,'),
#  (['Darmstadt;', 'no,'], 'not'),
#  (['Darmstadt,', 'but'], 'something'),
#  (['but', 'something'], 'American.'),
#  (['something', 'American.'], 'Yes,'),
#  (['American.', 'Yes,'], 'but'),
#  (['Yes,', 'but'], 'then,'),
#  (['but', 'then,'], 'Darmstadt'),
#  (['then,', 'Darmstadt'], 'was'),
#  (['Darmstadt', 'was'], 'in'),
#  (['America.', 'Yes,'], 'Alabin'),
#  (['Yes,', 'Alabin'], 'was'),
#  (['Alabin', 'was'], 'giving'),
#  (['was', 'giving'], 'a'),
#  (['giving', 'a'], 'dinner'),
#  (['a', 'dinner'], 'on'),
#  (['dinner', 'on'], 'glass'),
#  (['on', 'glass'], 'tables,'),
#  (['glass', 'tables,'], 'and'),
#  (['tables,', 'and'], 'the'),
#  (['and', 'the'], 'tables'),
#  (['sang,', '_Il'], 'mio'),
#  (['_Il', 'mio'], 'tesoro_--not'),
#  (['mio', 'tesoro_--not'], '_Il'),
#  (['tesoro_--not', '_Il'], 'mio'),
#  (['_Il', 'mio'], 'tesoro_'),
#  (['mio', 'tesoro_'], 'though,'),
#  (['tesoro_', 'though,'], 'but'),
#  (['though,', 'but'], 'something'),
#  (['but', 'something'], 'better,'),
#  (['and', 'there'], 'were'),
#  (['there', 'were'], 'some'),
#  (['were', 'some'], 'sort'),
#  (['some', 'sort'], 'of'),
#  (['sort', 'of'], 'little'),
#  (['of', 'little'], 'decanters'),
#  (['little', 'decanters'], 'on'),
#  (['decanters', 'on'], 'the'),
#  (['on', 'the'], 'table,'),
#  (['the', 'table,'], 'and'),
#  (['table,', 'and'], 'they'),
#  (['and', 'they'], 'were'),
#  (['women,', 'too,"'], 'he'),
#  (['too,"', 'he'], 'remembered.'),
#  (['Stepan', "Arkadyevitch's"], 'eyes'),
#  (["Arkadyevitch's", 'eyes'], 'twinkled'),
#  (['eyes', 'twinkled'], 'gaily,'),
#  (['twinkled', 'gaily,'], 'and'),
#  (['gaily,', 'and'], 'he'),
#  (['and', 'he'], 'pondered'),
#  (['he', 'pondered'], 'with'),
#  (['pondered', 'with'], 'a'),
#  (['with', 'a'], 'smile.'),
#  (['"Yes,', 'it'], 'was'),
#  (['it', 'was'], 'nice,'),
#  (['was', 'nice,'], 'very'),
#  (['nice,', 'very'], 'nice.'),
#  (['very', 'nice.'], 'There'),
#  (['nice.', 'There'], 'was'),
#  (['There', 'was'], 'a'),
#  (['was', 'a'], 'great'),
#  (['a', 'great'], 'deal'),
#  (['great', 'deal'], 'more'),
#  (['deal', 'more'], 'that'),
#  (['more', 'that'], 'was'),
#  (['delightful,', 'only'], "there's"),
#  (['only', "there's"], 'no'),
#  (["there's", 'no'], 'putting'),
#  (['no', 'putting'], 'it'),
#  (['putting', 'it'], 'into'),
#  (['it', 'into'], 'words,'),
#  (['into', 'words,'], 'or'),
#  (['words,', 'or'], 'even'),
#  (['or', 'even'], 'expressing'),
#  (['even', 'expressing'], 'it'),
#  (['in', "one's"], 'thoughts'),
#  (["one's", 'thoughts'], 'awake."'),
#  (['thoughts', 'awake."'], 'And'),
#  (['awake."', 'And'], 'noticing'),
#  (['And', 'noticing'], 'a'),
#  (['noticing', 'a'], 'gleam'),
#  (['a', 'gleam'], 'of'),
#  (['gleam', 'of'], 'light'),
#  (['of', 'light'], 'peeping'),
#  (['light', 'peeping'], 'in'),
#  (['beside', 'one'], 'of'),
#  (['one', 'of'], 'the'),
#  (['of', 'the'], 'serge'),
#  (['the', 'serge'], 'curtains,'),
#  (['serge', 'curtains,'], 'he'),
#  (['curtains,', 'he'], 'cheerfully'),
#  (['he', 'cheerfully'], 'dropped'),
#  (['cheerfully', 'dropped'], 'his'),
#  (['dropped', 'his'], 'feet'),
#  (['his', 'feet'], 'over'),
#  (['the', 'edge'], 'of'),
#  (['edge', 'of'], 'the'),
#  (['of', 'the'], 'sofa,'),
#  (['the', 'sofa,'], 'and'),
#  (['sofa,', 'and'], 'felt'),
#  (['and', 'felt'], 'about'),
#  (['felt', 'about'], 'with'),
#  (['about', 'with'], 'them'),
#  (['with', 'them'], 'for'),
#  (['them', 'for'], 'his'),
#  (['for', 'his'], 'slippers,'),
#  (['his', 'slippers,'], 'a'),
#  (['present', 'on'], 'his'),
#  (['on', 'his'], 'last'),
#  (['his', 'last'], 'birthday,'),
#  (['last', 'birthday,'], 'worked'),
#  (['birthday,', 'worked'], 'for'),
#  (['worked', 'for'], 'him'),
#  (['for', 'him'], 'by'),
#  (['him', 'by'], 'his'),
#  (['by', 'his'], 'wife'),
#  (['his', 'wife'], 'on'),
#  (['wife', 'on'], 'gold-colored'),
#  (['morocco.', 'And,'], 'as'),
#  (['And,', 'as'], 'he'),
#  (['as', 'he'], 'had'),
#  (['he', 'had'], 'done'),
#  (['had', 'done'], 'every'),
#  (['done', 'every'], 'day'),
#  (['every', 'day'], 'for'),
#  (['day', 'for'], 'the'),
#  (['for', 'the'], 'last'),
#  (['the', 'last'], 'nine'),
#  (['last', 'nine'], 'years,'),
#  (['nine', 'years,'], 'he'),
#  (['stretched', 'out'], 'his'),
#  (['out', 'his'], 'hand,'),
#  (['his', 'hand,'], 'without'),
#  (['hand,', 'without'], 'getting'),
#  (['without', 'getting'], 'up,'),
#  (['getting', 'up,'], 'towards'),
#  (['up,', 'towards'], 'the'),
#  (['towards', 'the'], 'place'),
#  (['the', 'place'], 'where'),
#  (['place', 'where'], 'his'),
#  (['dressing-gown', 'always'], 'hung'),
#  (['always', 'hung'], 'in'),
#  (['hung', 'in'], 'his'),
#  (['in', 'his'], 'bedroom.'),
#  (['his', 'bedroom.'], 'And'),
#  (['bedroom.', 'And'], 'thereupon'),
#  (['And', 'thereupon'], 'he'),
#  (['thereupon', 'he'], 'suddenly'),
#  (['remembered', 'that'], 'he'),
#  (['that', 'he'], 'was'),
#  (['he', 'was'], 'not'),
#  (['was', 'not'], 'sleeping'),
#  (['not', 'sleeping'], 'in'),
#  (['sleeping', 'in'], 'his'),
#  (['in', 'his'], "wife's"),
#  (['his', "wife's"], 'room,'),
#  (["wife's", 'room,'], 'but'),
#  (['room,', 'but'], 'in'),
#  (['but', 'in'], 'his'),
#  (['study,', 'and'], 'why:'),
#  (['and', 'why:'], 'the'),
#  (['why:', 'the'], 'smile'),
#  (['the', 'smile'], 'vanished'),
#  (['smile', 'vanished'], 'from'),
#  (['vanished', 'from'], 'his'),
#  (['from', 'his'], 'face,'),
#  (['his', 'face,'], 'he'),
#  (['face,', 'he'], 'knitted'),
#  (['he', 'knitted'], 'his'),
#  (['knitted', 'his'], 'brows.'),
#  (['"Ah,', 'ah,'], 'ah!'),
#  (['ah,', 'ah!'], 'Oo!..."'),
#  (['ah!', 'Oo!..."'], 'he'),
#  (['Oo!..."', 'he'], 'muttered,'),
#  (['he', 'muttered,'], 'recalling'),
#  (['muttered,', 'recalling'], 'everything'),
#  (['recalling', 'everything'], 'that'),
#  (['everything', 'that'], 'had'),
#  (['happened.', 'And'], 'again'),
#  (['And', 'again'], 'every'),
#  (['again', 'every'], 'detail'),
#  (['every', 'detail'], 'of'),
#  (['detail', 'of'], 'his'),
#  (['of', 'his'], 'quarrel'),
#  (['his', 'quarrel'], 'with'),
#  (['quarrel', 'with'], 'his'),
#  (['with', 'his'], 'wife'),
#  (['his', 'wife'], 'was'),
#  (['present', 'to'], 'his'),
#  (['to', 'his'], 'imagination,'),
#  (['his', 'imagination,'], 'all'),
#  (['imagination,', 'all'], 'the'),
#  (['all', 'the'], 'hopelessness'),
#  (['the', 'hopelessness'], 'of'),
#  (['hopelessness', 'of'], 'his'),
#  (['of', 'his'], 'position,'),
#  (['his', 'position,'], 'and'),
#  (['worst', 'of'], 'all,'),
#  (['of', 'all,'], 'his'),
#  (['all,', 'his'], 'own'),
#  (['his', 'own'], 'fault.'),
#  (['"Yes,', 'she'], "won't"),
#  (['she', "won't"], 'forgive'),
#  (["won't", 'forgive'], 'me,'),
#  (['forgive', 'me,'], 'and'),
#  (['me,', 'and'], 'she'),
#  (['and', 'she'], "can't"),
#  (['she', "can't"], 'forgive'),
#  (["can't", 'forgive'], 'me.'),
#  (['forgive', 'me.'], 'And'),
#  (['me.', 'And'], 'the'),
#  (['And', 'the'], 'most'),
#  (['the', 'most'], 'awful'),
#  (['thing', 'about'], 'it'),
#  (['about', 'it'], 'is'),
#  (['it', 'is'], 'that'),
#  (['is', 'that'], "it's"),
#  (['that', "it's"], 'all'),
#  (["it's", 'all'], 'my'),
#  (['all', 'my'], 'fault--all'),
#  (['my', 'fault--all'], 'my'),
#  (['fault--all', 'my'], 'fault,'),
#  (['my', 'fault,'], 'though'),
#  (['fault,', 'though'], "I'm"),
#  (['though', "I'm"], 'not'),
#  (['to', 'blame.'], "That's"),
#  (['blame.', "That's"], 'the'),
#  (["That's", 'the'], 'point'),
#  (['the', 'point'], 'of'),
#  (['point', 'of'], 'the'),
#  (['of', 'the'], 'whole'),
#  (['the', 'whole'], 'situation,"'),
#  (['whole', 'situation,"'], 'he'),
#  (['situation,"', 'he'], 'reflected.'),
#  (['he', 'reflected.'], '"Oh,'),
#  (['oh,', 'oh!"'], 'he'),
#  (['oh!"', 'he'], 'kept'),
#  (['he', 'kept'], 'repeating'),
#  (['kept', 'repeating'], 'in'),
#  (['repeating', 'in'], 'despair,'),
#  (['in', 'despair,'], 'as'),
#  (['despair,', 'as'], 'he'),
#  (['as', 'he'], 'remembered'),
#  (['he', 'remembered'], 'the'),
#  (['remembered', 'the'], 'acutely'),
#  (['painful', 'sensations'], 'caused'),
#  (['sensations', 'caused'], 'him'),
#  (['caused', 'him'], 'by'),
#  (['him', 'by'], 'this'),
#  (['by', 'this'], 'quarrel.'),
#  (['Most', 'unpleasant'], 'of'),
#  (['unpleasant', 'of'], 'all'),
#  (['of', 'all'], 'was'),
#  (['all', 'was'], 'the'),
#  (['was', 'the'], 'first'),
#  (['the', 'first'], 'minute'),
#  (['first', 'minute'], 'when,'),
#  (['minute', 'when,'], 'on'),
#  (['when,', 'on'], 'coming,'),
#  (['on', 'coming,'], 'happy'),
#  (['coming,', 'happy'], 'and'),
#  (['good-humored,', 'from'], 'the'),
#  (['from', 'the'], 'theater,'),
#  (['the', 'theater,'], 'with'),
#  (['theater,', 'with'], 'a'),
#  (['with', 'a'], 'huge'),
#  (['a', 'huge'], 'pear'),
#  (['huge', 'pear'], 'in'),
#  (['pear', 'in'], 'his'),
#  (['in', 'his'], 'hand'),
#  (['his', 'hand'], 'for'),
#  (['hand', 'for'], 'his'),
#  (['wife,', 'he'], 'had'),
#  (['he', 'had'], 'not'),
#  (['had', 'not'], 'found'),
#  (['not', 'found'], 'his'),
#  (['found', 'his'], 'wife'),
#  (['his', 'wife'], 'in'),
#  (['wife', 'in'], 'the'),
#  (['in', 'the'], 'drawing-room,'),
#  (['the', 'drawing-room,'], 'to'),
#  (['drawing-room,', 'to'], 'his'),
#  (['to', 'his'], 'surprise'),
#  (['his', 'surprise'], 'had'),
#  (['not', 'found'], 'her'),
#  (['found', 'her'], 'in'),
#  (['her', 'in'], 'the'),
#  (['in', 'the'], 'study'),
#  (['the', 'study'], 'either,'),
#  (['study', 'either,'], 'and'),
#  (['either,', 'and'], 'saw'),
#  (['and', 'saw'], 'her'),
#  (['saw', 'her'], 'at'),
#  (['her', 'at'], 'last'),
#  (['at', 'last'], 'in'),
#  (['last', 'in'], 'her'),
#  (['in', 'her'], 'bedroom'),
#  (['with', 'the'], 'unlucky'),
#  (['the', 'unlucky'], 'letter'),
#  (['unlucky', 'letter'], 'that'),
#  (['letter', 'that'], 'revealed'),
#  (['that', 'revealed'], 'everything'),
#  (['revealed', 'everything'], 'in'),
#  (['everything', 'in'], 'her'),
#  (['in', 'her'], 'hand.'),
#  (['She,', 'his'], 'Dolly,'),
#  (['his', 'Dolly,'], 'forever'),
#  (['Dolly,', 'forever'], 'fussing'),
#  (['forever', 'fussing'], 'and'),
#  (['fussing', 'and'], 'worrying'),
#  (['and', 'worrying'], 'over'),
#  (['worrying', 'over'], 'household'),
#  (['over', 'household'], 'details,'),
#  (['household', 'details,'], 'and'),
#  (['limited', 'in'], 'her'),
#  (['in', 'her'], 'ideas,'),
#  (['her', 'ideas,'], 'as'),
#  (['ideas,', 'as'], 'he'),
#  (['as', 'he'], 'considered,'),
#  (['he', 'considered,'], 'was'),
#  (['considered,', 'was'], 'sitting'),
#  (['was', 'sitting'], 'perfectly'),
#  (['sitting', 'perfectly'], 'still'),
#  (['perfectly', 'still'], 'with'),
#  (['the', 'letter'], 'in'),
#  (['letter', 'in'], 'her'),
#  (['in', 'her'], 'hand,'),
#  (['her', 'hand,'], 'looking'),
#  (['hand,', 'looking'], 'at'),
#  (['looking', 'at'], 'him'),
#  (['at', 'him'], 'with'),
#  (['him', 'with'], 'an'),
#  (['with', 'an'], 'expression'),
#  (['an', 'expression'], 'of'),
#  (['expression', 'of'], 'horror,'),
#  (['despair,', 'and'], 'indignation.'),
#  (['"What\'s', 'this?'], 'this?"'),
#  (['this?', 'this?"'], 'she'),
#  (['this?"', 'she'], 'asked,'),
#  (['she', 'asked,'], 'pointing'),
#  (['asked,', 'pointing'], 'to'),
#  (['pointing', 'to'], 'the'),
#  (['to', 'the'], 'letter.'),
#  (['And', 'at'], 'this'),
#  (['at', 'this'], 'recollection,'),
#  (['this', 'recollection,'], 'Stepan'),
#  (['recollection,', 'Stepan'], 'Arkadyevitch,'),
#  (['Stepan', 'Arkadyevitch,'], 'as'),
#  (['Arkadyevitch,', 'as'], 'is'),
#  (['as', 'is'], 'so'),
#  (['is', 'so'], 'often'),
#  (['so', 'often'], 'the'),
#  (['often', 'the'], 'case,'),
#  (['was', 'not'], 'so'),
#  (['not', 'so'], 'much'),
#  (['so', 'much'], 'annoyed'),
#  (['much', 'annoyed'], 'at'),
#  (['annoyed', 'at'], 'the'),
#  (['at', 'the'], 'fact'),
#  (['the', 'fact'], 'itself'),
#  (['fact', 'itself'], 'as'),
#  (['itself', 'as'], 'at'),
#  (['as', 'at'], 'the'),
#  (['at', 'the'], 'way'),
#  (['the', 'way'], 'in'),
#  (['way', 'in'], 'which'),
#  (['in', 'which'], 'he'),
#  (['which', 'he'], 'had'),
#  (['met', 'his'], "wife's"),
#  (['his', "wife's"], 'words.'),
#  (['There', 'happened'], 'to'),
#  (['happened', 'to'], 'him'),
#  (['to', 'him'], 'at'),
#  (['him', 'at'], 'that'),
#  (['at', 'that'], 'instant'),
#  (['that', 'instant'], 'what'),
#  (['instant', 'what'], 'does'),
#  (['what', 'does'], 'happen'),
#  (['does', 'happen'], 'to'),
#  (['happen', 'to'], 'people'),
#  (['to', 'people'], 'when'),
#  (['they', 'are'], 'unexpectedly'),
#  (['are', 'unexpectedly'], 'caught'),
#  (['unexpectedly', 'caught'], 'in'),
#  (['caught', 'in'], 'something'),
#  (['in', 'something'], 'very'),
#  (['something', 'very'], 'disgraceful.'),
#  (['very', 'disgraceful.'], 'He'),
#  (['disgraceful.', 'He'], 'did'),
#  (['He', 'did'], 'not'),
#  (['succeed', 'in'], 'adapting'),
#  (['in', 'adapting'], 'his'),
#  (['adapting', 'his'], 'face'),
#  (['his', 'face'], 'to'),
#  (['face', 'to'], 'the'),
#  (['to', 'the'], 'position'),
#  (['the', 'position'], 'in'),
#  (['position', 'in'], 'which'),
#  (['in', 'which'], 'he'),
#  (['which', 'he'], 'was'),
#  (['he', 'was'], 'placed'),
#  (['towards', 'his'], 'wife'),
#  (['his', 'wife'], 'by'),
#  (['wife', 'by'], 'the'),
#  (['by', 'the'], 'discovery'),
#  (['the', 'discovery'], 'of'),
#  (['discovery', 'of'], 'his'),
#  (['of', 'his'], 'fault.'),
#  (['his', 'fault.'], 'Instead'),
#  (['fault.', 'Instead'], 'of'),
#  (['Instead', 'of'], 'being'),
#  (['of', 'being'], 'hurt,'),
#  (['denying,', 'defending'], 'himself,'),
#  (['defending', 'himself,'], 'begging'),
#  (['himself,', 'begging'], 'forgiveness,'),
#  (['begging', 'forgiveness,'], 'instead'),
#  (['forgiveness,', 'instead'], 'of'),
#  (['instead', 'of'], 'remaining'),
#  (['indifferent', 'even--anything'], 'would'),
#  (['even--anything', 'would'], 'have'),
#  (['would', 'have'], 'been'),
#  (['have', 'been'], 'better'),
#  (['been', 'better'], 'than'),
#  (['better', 'than'], 'what'),
#  (['than', 'what'], 'he'),
#  (['what', 'he'], 'did'),
#  (['do--his', 'face'], 'utterly'),
#  (['face', 'utterly'], 'involuntarily'),
#  (['utterly', 'involuntarily'], '(reflex'),
#  (['involuntarily', '(reflex'], 'spinal'),
#  (['(reflex', 'spinal'], 'action,'),
#  (['spinal', 'action,'], 'reflected'),
#  (['Stepan', 'Arkadyevitch,'], 'who'),
#  (['Arkadyevitch,', 'who'], 'was'),
#  (['who', 'was'], 'fond'),
#  (['was', 'fond'], 'of'),
#  (['fond', 'of'], 'physiology)--utterly'),
#  (['of', 'physiology)--utterly'], 'involuntarily'),
#  (['assumed', 'its'], 'habitual,'),
#  (['its', 'habitual,'], 'good-humored,'),
#  (['habitual,', 'good-humored,'], 'and'),
#  (['good-humored,', 'and'], 'therefore'),
#  (['and', 'therefore'], 'idiotic'),
#  (['therefore', 'idiotic'], 'smile.'),
#  (['This', 'idiotic'], 'smile'),
#  (['idiotic', 'smile'], 'he'),
#  (['smile', 'he'], 'could'),
#  (['he', 'could'], 'not'),
#  (['could', 'not'], 'forgive'),
#  (['not', 'forgive'], 'himself.'),
#  (['forgive', 'himself.'], 'Catching'),
#  (['himself.', 'Catching'], 'sight'),
#  (['Catching', 'sight'], 'of'),
#  (['sight', 'of'], 'that'),
#  (['smile,', 'Dolly'], 'shuddered'),
#  (['Dolly', 'shuddered'], 'as'),
#  (['shuddered', 'as'], 'though'),
#  (['as', 'though'], 'at'),
#  (['though', 'at'], 'physical'),
#  (['at', 'physical'], 'pain,'),
#  (['physical', 'pain,'], 'broke'),
#  (['pain,', 'broke'], 'out'),
#  (['broke', 'out'], 'with'),
#  (['out', 'with'], 'her'),
#  (['characteristic', 'heat'], 'into'),
#  (['heat', 'into'], 'a'),
#  (['into', 'a'], 'flood'),
#  (['a', 'flood'], 'of'),
#  (['flood', 'of'], 'cruel'),
#  (['of', 'cruel'], 'words,'),
#  (['cruel', 'words,'], 'and'),
#  (['words,', 'and'], 'rushed'),
#  (['and', 'rushed'], 'out'),
#  (['rushed', 'out'], 'of'),
#  (['out', 'of'], 'the'),
#  (['room.', 'Since'], 'then'),
#  (['Since', 'then'], 'she'),
#  (['then', 'she'], 'had'),
#  (['she', 'had'], 'refused'),
#  (['had', 'refused'], 'to'),
#  (['refused', 'to'], 'see'),
#  (['to', 'see'], 'her'),
#  (['see', 'her'], 'husband.'),
#  (['"It\'s', 'that'], 'idiotic'),
#  (['that', 'idiotic'], 'smile'),
#  (['idiotic', 'smile'], "that's"),
#  (['smile', "that's"], 'to'),
#  (["that's", 'to'], 'blame'),
#  (['to', 'blame'], 'for'),
#  (['blame', 'for'], 'it'),
#  (['for', 'it'], 'all,"'),
#  (['it', 'all,"'], 'thought'),
#  (['all,"', 'thought'], 'Stepan'),
#  (['"But', "what's"], 'to'),
#  (["what's", 'to'], 'be'),
#  (['to', 'be'], 'done?'),
#  (['be', 'done?'], "What's"),
#  (['done?', "What's"], 'to'),
#  (["What's", 'to'], 'be'),
#  (['to', 'be'], 'done?"'),
#  (['be', 'done?"'], 'he'),
#  (['done?"', 'he'], 'said'),
#  (['he', 'said'], 'to'),
#  (['said', 'to'], 'himself'),
#  (['to', 'himself'], 'in'),
#  (['despair,', 'and'], 'found'),
#  (['and', 'found'], 'no'),
#  (['found', 'no'], 'answer.'),
#  (['Stepan', 'Arkadyevitch'], 'was'),
#  (['Arkadyevitch', 'was'], 'a'),
#  (['was', 'a'], 'truthful'),
#  (['a', 'truthful'], 'man'),
#  (['truthful', 'man'], 'in'),
#  (['man', 'in'], 'his'),
#  (['in', 'his'], 'relations'),
#  (['his', 'relations'], 'with'),
#  (['relations', 'with'], 'himself.'),
#  (['with', 'himself.'], 'He'),
#  (['was', 'incapable'], 'of'),
#  (['incapable', 'of'], 'deceiving'),
#  (['of', 'deceiving'], 'himself'),
#  (['deceiving', 'himself'], 'and'),
#  (['himself', 'and'], 'persuading'),
#  (['and', 'persuading'], 'himself'),
#  (['persuading', 'himself'], 'that'),
#  (['himself', 'that'], 'he'),
#  (['repented', 'of'], 'his'),
#  (['of', 'his'], 'conduct.'),
#  (['his', 'conduct.'], 'He'),
#  (['conduct.', 'He'], 'could'),
#  (['He', 'could'], 'not'),
#  (['could', 'not'], 'at'),
#  (['not', 'at'], 'this'),
#  (['at', 'this'], 'date'),
#  (['this', 'date'], 'repent'),
#  (['date', 'repent'], 'of'),
#  (['repent', 'of'], 'the'),
#  (['of', 'the'], 'fact'),
#  (['that', 'he,'], 'a'),
#  (['he,', 'a'], 'handsome,'),
#  (['a', 'handsome,'], 'susceptible'),
#  (['handsome,', 'susceptible'], 'man'),
#  (['susceptible', 'man'], 'of'),
#  (['man', 'of'], 'thirty-four,'),
#  (['of', 'thirty-four,'], 'was'),
#  (['thirty-four,', 'was'], 'not'),
#  (['was', 'not'], 'in'),
#  (['not', 'in'], 'love'),
#  (['with', 'his'], 'wife,'),
#  (['his', 'wife,'], 'the'),
#  (['wife,', 'the'], 'mother'),
#  (['the', 'mother'], 'of'),
#  (['mother', 'of'], 'five'),
#  (['of', 'five'], 'living'),
#  (['five', 'living'], 'and'),
#  (['living', 'and'], 'two'),
#  (['and', 'two'], 'dead'),
#  (['two', 'dead'], 'children,'),
#  (['dead', 'children,'], 'and'),
#  (['children,', 'and'], 'only'),
#  (['a', 'year'], 'younger'),
#  (['year', 'younger'], 'than'),
#  (['younger', 'than'], 'himself.'),
#  (['than', 'himself.'], 'All'),
#  (['himself.', 'All'], 'he'),
#  (['All', 'he'], 'repented'),
#  (['he', 'repented'], 'of'),
#  (['repented', 'of'], 'was'),
#  (['of', 'was'], 'that'),
#  (['was', 'that'], 'he'),
#  (['that', 'he'], 'had'),
#  (['he', 'had'], 'not'),
#  (['succeeded', 'better'], 'in'),
#  (['better', 'in'], 'hiding'),
#  (['in', 'hiding'], 'it'),
#  (['hiding', 'it'], 'from'),
#  (['it', 'from'], 'his'),
#  (['from', 'his'], 'wife.'),
#  (['his', 'wife.'], 'But'),
#  (['wife.', 'But'], 'he'),
#  (['But', 'he'], 'felt'),
#  (['he', 'felt'], 'all'),
#  (['felt', 'all'], 'the'),
#  (['difficulty', 'of'], 'his'),
#  (['of', 'his'], 'position'),
#  (['his', 'position'], 'and'),
#  (['position', 'and'], 'was'),
#  (['and', 'was'], 'sorry'),
#  (['was', 'sorry'], 'for'),
#  (['sorry', 'for'], 'his'),
#  (['for', 'his'], 'wife,'),
#  (['his', 'wife,'], 'his'),
#  (['wife,', 'his'], 'children,'),
#  (['his', 'children,'], 'and'),
#  (['himself.', 'Possibly'], 'he'),
#  (['Possibly', 'he'], 'might'),
#  (['he', 'might'], 'have'),
#  (['might', 'have'], 'managed'),
#  (['have', 'managed'], 'to'),
#  (['managed', 'to'], 'conceal'),
#  (['to', 'conceal'], 'his'),
#  (['conceal', 'his'], 'sins'),
#  (['his', 'sins'], 'better'),
#  (['sins', 'better'], 'from'),
#  (['his', 'wife'], 'if'),
#  (['wife', 'if'], 'he'),
#  (['if', 'he'], 'had'),
#  (['he', 'had'], 'anticipated'),
#  (['had', 'anticipated'], 'that'),
#  (['anticipated', 'that'], 'the'),
#  (['that', 'the'], 'knowledge'),
#  (['the', 'knowledge'], 'of'),
#  (['knowledge', 'of'], 'them'),
#  (['of', 'them'], 'would'),
#  (['them', 'would'], 'have'),
#  (['would', 'have'], 'had'),
#  (['such', 'an'], 'effect'),
#  (['an', 'effect'], 'on'),
#  (['effect', 'on'], 'her.'),
#  (['on', 'her.'], 'He'),
#  (['her.', 'He'], 'had'),
#  (['He', 'had'], 'never'),
#  (['had', 'never'], 'clearly'),
#  (['never', 'clearly'], 'thought'),
#  (['clearly', 'thought'], 'out'),
#  (['thought', 'out'], 'the'),
#  (['out', 'the'], 'subject,'),
#  (['the', 'subject,'], 'but'),
#  (['he', 'had'], 'vaguely'),
#  (['had', 'vaguely'], 'conceived'),
#  (['vaguely', 'conceived'], 'that'),
#  (['conceived', 'that'], 'his'),
#  (['that', 'his'], 'wife'),
#  (['his', 'wife'], 'must'),
#  (['wife', 'must'], 'long'),
#  (['must', 'long'], 'ago'),
#  (['long', 'ago'], 'have'),
#  (['ago', 'have'], 'suspected'),
#  (['have', 'suspected'], 'him'),
#  (['of', 'being'], 'unfaithful'),
#  (['being', 'unfaithful'], 'to'),
#  (['unfaithful', 'to'], 'her,'),
#  (['to', 'her,'], 'and'),
#  (['her,', 'and'], 'shut'),
#  (['and', 'shut'], 'her'),
#  (['shut', 'her'], 'eyes'),
#  (['her', 'eyes'], 'to'),
#  (['eyes', 'to'], 'the'),
#  (['to', 'the'], 'fact.'),
#  (['the', 'fact.'], 'He'),
#  (['fact.', 'He'], 'had'),
#  (['He', 'had'], 'even'),
#  (['supposed', 'that'], 'she,'),
#  (['that', 'she,'], 'a'),
#  (['she,', 'a'], 'worn-out'),
#  (['a', 'worn-out'], 'woman'),
#  (['worn-out', 'woman'], 'no'),
#  (['woman', 'no'], 'longer'),
#  (['no', 'longer'], 'young'),
#  (['longer', 'young'], 'or'),
#  (['young', 'or'], 'good-looking,'),
#  (['or', 'good-looking,'], 'and'),
#  (['in', 'no'], 'way'),
#  (['no', 'way'], 'remarkable'),
#  (['way', 'remarkable'], 'or'),
#  (['remarkable', 'or'], 'interesting,'),
#  (['or', 'interesting,'], 'merely'),
#  (['interesting,', 'merely'], 'a'),
#  (['merely', 'a'], 'good'),
#  (['a', 'good'], 'mother,'),
#  (['good', 'mother,'], 'ought'),
#  (['mother,', 'ought'], 'from'),
#  (['ought', 'from'], 'a'),
#  (['sense', 'of'], 'fairness'),
#  (['of', 'fairness'], 'to'),
#  (['fairness', 'to'], 'take'),
#  (['to', 'take'], 'an'),
#  (['take', 'an'], 'indulgent'),
#  (['an', 'indulgent'], 'view.'),
#  (['indulgent', 'view.'], 'It'),
#  (['view.', 'It'], 'had'),
#  (['It', 'had'], 'turned'),
#  (['had', 'turned'], 'out'),
#  (['turned', 'out'], 'quite'),
#  (['out', 'quite'], 'the'),
#  (['"Oh,', "it's"], 'awful!'),
#  (["it's", 'awful!'], 'oh'),
#  (['awful!', 'oh'], 'dear,'),
#  (['oh', 'dear,'], 'oh'),
#  (['dear,', 'oh'], 'dear!'),
#  (['oh', 'dear!'], 'awful!"'),
#  (['dear!', 'awful!"'], 'Stepan'),
#  (['awful!"', 'Stepan'], 'Arkadyevitch'),
#  (['Stepan', 'Arkadyevitch'], 'kept'),
#  (['repeating', 'to'], 'himself,'),
#  (['to', 'himself,'], 'and'),
#  (['himself,', 'and'], 'he'),
#  (['and', 'he'], 'could'),
#  (['he', 'could'], 'think'),
#  (['could', 'think'], 'of'),
#  (['think', 'of'], 'nothing'),
#  (['of', 'nothing'], 'to'),
#  (['nothing', 'to'], 'be'),
#  (['to', 'be'], 'done.'),
#  (['be', 'done.'], '"And'),
#  (['done.', '"And'], 'how'),
#  (['well', 'things'], 'were'),
#  (['things', 'were'], 'going'),
#  (['were', 'going'], 'up'),
#  (['going', 'up'], 'till'),
#  (['up', 'till'], 'now!'),
#  (['till', 'now!'], 'how'),
#  (['now!', 'how'], 'well'),
#  (['how', 'well'], 'we'),
#  (['well', 'we'], 'got'),
#  (['we', 'got'], 'on!'),
#  (['got', 'on!'], 'She'),
#  (['on!', 'She'], 'was'),
#  (['contented', 'and'], 'happy'),
#  (['and', 'happy'], 'in'),
#  (['happy', 'in'], 'her'),
#  (['in', 'her'], 'children;'),
#  ...]

# %%
wrd_to_idx["Stepan"]
# Out:
# 1686

# %%
print(wrd_to_idx["Arkadyevitch"])
# Out:
# 3357

# %%
#numpy.argsort(-y_pred.detach().squeeze(-1))
# Out:
# tensor([[7463, 5744, 1174,  ..., 5947, 3537, 4323]])

# %%
# for k,v in wrd_to_idx.items():
#     if v == 1174:
#         print(k)

# %%
# Save Model
torch.save(model.state_dict(), "word2vec_pytorch")

# %%
# Loading Model
model = NGramLanguageModel(len(word_lst), EMBEDDING_DIM, CONTEXT_SIZE)
model.load_state_dict(torch.load('word2vec_model'), strict=False)
# Out:
# <All keys matched successfully>

# %%
y_pred = model(torch.tensor([1686,3357],dtype=torch.long))

# %%
top_n, top_i = y_pred.topk(1)

# %%
for k,v in wrd_to_idx.items():
    if v == top_i.item():
        print(k)
# Out:
# impatiently
